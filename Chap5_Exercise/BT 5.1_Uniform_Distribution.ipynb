# %% [markdown]
# # **BT thực hành 5.2: UNIFORM Distribution**
#
#
# > Cập nhật: **07/2023**

# %% [markdown]
# ---
# ## **Bài toán 1:**
# - Một cửa hàng trong một năm (365 ngày) bán mỗi ngày từ 10 đến 40 sản phẩm
# ---

# %%
## Thư viện
import numpy             as np
import matplotlib.pyplot as plt

from scipy.stats         import stats, uniform

# %%
## Mô hình hóa: các giá trị tham số
n = 365 # trials
a = 10  # Min
b = 40  # Max

# %%
## Giả lập số liệu bán hàng của 365 ngày (tạo số liệu ngẫu nhiên)
data_uniform = np.random.uniform(a, b + 1, n).astype(int)

## from scipy.stats import uniform
## data_uniform = uniform.rvs(size = n, loc = a, scale = b - a).astype(int)

data_uniform
# Out:
# array([30, 28, 28, 34, 15, 31, 12, 25, 31, 11, 18, 31, 35, 34, 25, 15, 23,
#        38, 16, 12, 37, 31, 40, 10, 38, 12, 28, 11, 33, 28, 25, 32, 11, 33,
#        18, 14, 20, 30, 32, 36, 34, 21, 23, 21, 33, 37, 18, 32, 18, 25, 14,
#        31, 15, 30, 37, 11, 35, 13, 24, 31, 11, 22, 22, 30, 33, 27, 21, 32,
#        21, 14, 25, 40, 11, 14, 17, 16, 34, 26, 13, 37, 25, 10, 25, 23, 26,
#        36, 32, 38, 30, 29, 19, 33, 13, 34, 20, 19, 29, 36, 11, 35, 29, 13,
#        17, 33, 35, 38, 18, 21, 30, 26, 22, 33, 22, 13, 34, 40, 39, 14, 27,
#        29, 10, 13, 27, 30, 37, 15, 20, 16, 36, 22, 10, 11, 12, 21, 33, 14,
#        28, 18, 10, 29, 38, 27, 23, 15, 31, 36, 14, 24, 38, 23, 28, 40, 20,
#        25, 28, 16, 29, 30, 11, 28, 23, 13, 17, 31, 27, 20, 19, 27, 23, 29,
#        39, 23, 32, 10, 40, 24, 26, 24, 32, 24, 24, 38, 17, 29, 25, 31, 24,
#        27, 10, 36, 13, 36, 24, 39, 39, 38, 15, 29, 28, 11, 12, 38, 34, 36,
#        36, 37, 39, 21, 27, 30, 35, 33, 26, 18, 14, 28, 11, 34, 31, 26, 31,
#        33, 36, 22, 30, 11, 13, 32, 32, 31, 17, 24, 24, 27, 20, 23, 17, 17,
#        32, 31, 16, 20, 11, 15, 14, 36, 26, 27, 12, 33, 19, 30, 11, 24, 35,
#        20, 14, 29, 24, 14, 13, 17, 30, 36, 39, 12, 40, 18, 34, 31, 30, 11,
#        32, 13, 24, 22, 20, 24, 23, 33, 39, 34, 36, 15, 21, 30, 22, 29, 34,
#        15, 36, 18, 18, 29, 18, 20, 21, 25, 25, 31, 33, 21, 15, 38, 20, 22,
#        22, 33, 29, 23, 31, 27, 24, 39, 35, 36, 20, 13, 37, 16, 20, 11, 24,
#        17, 30, 18, 12, 37, 39, 36, 32, 25, 13, 32, 38, 37, 25, 39, 23, 38,
#        23, 16, 15, 18, 26, 20, 17, 21, 37, 34, 21, 15, 27, 23, 38, 10, 22,
#        15, 21, 24, 14, 25, 31, 15, 36])

# %%
## Vẽ biểu đồ histogram
plt.hist(data_uniform)
plt.title('Histogram (Uniform Distribution)')
plt.show()

# %%
## Tính xác suất 1 ngày bán không quá 15 sản phẩm: P(X <= 15) = F(15)
p = (15 - a) / (b - a)
p
# Out:
# 0.16666666666666666

# %%
## Lưu ý: Hàm scipy.stats.uniform() áp dụng cho biến LIÊN TỤC !
dist = uniform(a, b - a) # (loc = a, loc + scale = b - a)
p    = dist.cdf(15)
p
# Out:
# 0.16666666666666666

# %%
## Tính xác suất 1 ngày bán từ 15 đến 30 sản phẩm: P(15 <= X <= 30) = F(30) - F(15)
p = (30 - 15) / (b - a)
p
# Out:
# 0.5

# %%
## Tính xác suất 1 ngày bán nhiều hơn 20 sản phẩm: P(X > 20) = 1 - P(X <= 20) = 1 - F(20)
p = (20 - a) / (b - a)
1 - p

##
# Out:
# 0.6666666666666667

# %% [markdown]
# ---
# ## **Bài toán 2:**
# Có 30 người tham gia trả lời một câu hỏi trong vòng 25 giây. Giả sử thời gian trả lời có phân phối đều.
# - Tính xác suất để 1 người tham gia sẽ trả lời trong vòng 6 giây.
# ---

# %%
## Mô hình hóa: các giá trị tham số
n = 30 # Trials
a = 0  # Min
b = 25 # Max

# %%
## Tính xác suất để trả lời trong vòng 6 giây: P(X <= 6) = F(6)
p = (6 - a) / (b - a)
p
# Out:
# 0.24

# %% [markdown]
# ---
# ## **Bài toán 3:**
# Thời gian bay của một chuyến bay từ thành phố A đến thành phố B mất khoảng 120 phút đến 140 phút. Giả sử thời gian bay có phân phối đều.
# - Tính xác suất của thời gian bay từ 120 phút đến 130 phút.
# - Tính kỳ vọng và phương sai.
# ---

# %%
## Mô hình hóa: các giá trị tham số
a = 120  # Min
b = 140  # Max

# %%
## Tính xác suất của thời gian bay từ 120 phút đến 130 phút: P(120 <= X <= 130) = F(130) - F(120)
p = (130 - 120) / (b - a)
p
# Out:
# 0.5

# %%
## Tính kỳ vọng và phương sai
exp, var = (a + b) / 2, (b - a)**2 / 12
exp, var
# Out:
# (130.0, 33.333333333333336)
